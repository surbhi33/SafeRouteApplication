# %%
import pandas as pd
import googlemaps 
import json

# %%
sf_crim_df = pd.read_csv('sfcrime.csv')
# Out:
# /Users/anishmukherjee/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
sf_crim_df[['Latitude','Longitude','Point']]
# Out:
#          Latitude   Longitude                                           Point
# 0       37.779992 -122.413487   POINT (-122.41348740024354 37.77999173926721)
# 1       37.775787 -122.427819   POINT (-122.42781910073226 37.77578657487239)
# 2       37.723944 -122.422830   POINT (-122.42283006837721 37.72394419349765)
# 3       37.775161 -122.403636    POINT (-122.40363551943442 37.7751608100771)
# 4       37.802755 -122.413623    POINT (-122.4136227157606 37.80275505740129)
# ...           ...         ...                                             ...
# 573438  37.785893 -122.412148   POINT (-122.41214750780264 37.78589292711297)
# 573439  37.780476 -122.476169  POINT (-122.47616919036905 37.780475849410344)
# 573440  37.754000 -122.389860   POINT (-122.38985954971992 37.75399971361786)
# 573441  37.777490 -122.433219  POINT (-122.43321873935555 37.777490366353746)
# 573442  37.711118 -122.450774   POINT (-122.45077402789384 37.71111756407944)
#
# [573443 rows x 3 columns]

# %%
sf_crim_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573443 entries, 0 to 573442
# Data columns (total 34 columns):
#  #   Column                                                Non-Null Count   Dtype
# ---  ------                                                --------------   -----
#  0   Incident Datetime                                     573443 non-null  object
#  1   Incident Date                                         573443 non-null  object
#  2   Incident Time                                         573443 non-null  object
#  3   Incident Year                                         573443 non-null  int64
#  4   Incident Day of Week                                  573443 non-null  object
#  5   Report Datetime                                       573443 non-null  object
#  6   Row ID                                                573443 non-null  int64
#  7   Incident ID                                           573443 non-null  int64
# ...

# %% [markdown]
# ### Response object

# %%
import requests

url = "https://maps.googleapis.com/maps/api/directions/json?origin=1422 Powell St&destination=101 Howard St&alternatives=true&key=AIzaSyCINW6uGcvCKu9J-8AkdKFt4YcBObovM94"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)

#print(response.text['routes'])
# Out:
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJYeM_MfKAhYARmBy9iUlgk-I",
#          "types" : [ "street_address" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJZ7KaIWWAhYARVLHSJi9FajM",
#          "types" : [ "premise" ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 37.7991912,
#                "lng" : -122.3912341
#             },
#             "southwest" : {
#                "lat" : 37.7910969,
#                "lng" : -122.4103637
#             }
#          },
#          "copyrights" : "Map data ©2022 Google",
#          "legs" : [
#             {
#                "distance" : {
#                   "text" : "1.5 mi",
#                   "value" : 2336
#                },
#                "duration" : {
#                   "text" : "9 mins",
#                   "value" : 529
#                },
# ...

# %%
route_info = json.loads(response.text)

# %%
route_info['geocoded_waypoints']
# Out:
# [{'geocoder_status': 'OK',
#   'place_id': 'ChIJYeM_MfKAhYARmBy9iUlgk-I',
#   'types': ['street_address']},
#  {'geocoder_status': 'OK',
#   'place_id': 'ChIJZ7KaIWWAhYARVLHSJi9FajM',
#   'types': ['premise']}]

# %% [markdown]
# ### Getting intermediate points

# %%
route_points = []
for point in route_info['routes'][0]['legs'][0]['steps']:
    route_points.append(point['end_location'])

# %%
route_info['status']
# Out:
# 'OK'

# %%
len(route_points)
# Out:
# 4

# %%
route_points
# Out:
# [{'lat': 37.7974619, 'lng': -122.4102964},
#  {'lat': 37.7991912, 'lng': -122.3977982},
#  {'lat': 37.792362, 'lng': -122.3912341},
#  {'lat': 37.7910969, 'lng': -122.3928065}]

# %%
route_info['routes'][0]['legs'][0]['steps']
# Out:
# [{'distance': {'text': '157 ft', 'value': 48},
#   'duration': {'text': '1 min', 'value': 16},
#   'end_location': {'lat': 37.7974619, 'lng': -122.4102964},
#   'html_instructions': 'Head <b>south</b> on <b>Powell St</b> toward <b>Broadway</b>',
#   'polyline': {'points': 'ykueFvgcjVD?NADAx@G'},
#   'start_location': {'lat': 37.7978914, 'lng': -122.4103637},
#   'travel_mode': 'DRIVING'},
#  {'distance': {'text': '0.7 mi', 'value': 1130},
#   'duration': {'text': '4 mins', 'value': 230},
#   'end_location': {'lat': 37.7991912, 'lng': -122.3977982},
#   'html_instructions': 'Turn <b>left</b> at the 1st cross street onto <b>Broadway</b><div style="font-size:0.9em">Pass by Wells Fargo Bank (on the right in 0.2&nbsp;mi)</div>',
#   'maneuver': 'turn-left',
#   'polyline': {'points': 'ciueFjgcjVNCACACCEACCC?KEq@C[Ei@IyAEk@Ei@Eo@KcBCc@AICa@AICc@AIC_@GeAEu@Ca@AUC]Cc@Ee@ASAIAMEi@KaBGgAEe@Ca@AUEm@CUIyACYIkAC_@Ca@Ca@Ek@GgAAQCUEm@GcAAEKuBGi@Ci@CYCa@QeCGo@CSAQESEKEMEKUg@'},
# ...

# %%
route_info
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJYeM_MfKAhYARmBy9iUlgk-I',
#    'types': ['street_address']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJZ7KaIWWAhYARVLHSJi9FajM',
#    'types': ['premise']}],
#  'routes': [{'bounds': {'northeast': {'lat': 37.7991912, 'lng': -122.3912341},
#     'southwest': {'lat': 37.7910969, 'lng': -122.4103637}},
#    'copyrights': 'Map data ©2022 Google',
#    'legs': [{'distance': {'text': '1.5 mi', 'value': 2336},
#      'duration': {'text': '9 mins', 'value': 529},
#      'end_address': 'University of San Francisco - Folger Building, 101 Howard St, San Francisco, CA 94105, USA',
#      'end_location': {'lat': 37.7910969, 'lng': -122.3928065},
#      'start_address': '1422 Powell St, San Francisco, CA 94133, USA',
#      'start_location': {'lat': 37.7978914, 'lng': -122.4103637},
#      'steps': [{'distance': {'text': '157 ft', 'value': 48},
#        'duration': {'text': '1 min', 'value': 16},
# ...

# %%
route_info.keys()
# Out:
# dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
route_info['routes'][]
# Out:
# [{'bounds': {'northeast': {'lat': 37.7991912, 'lng': -122.3912341},
#    'southwest': {'lat': 37.7910969, 'lng': -122.4103637}},
#   'copyrights': 'Map data ©2022 Google',
#   'legs': [{'distance': {'text': '1.5 mi', 'value': 2336},
#     'duration': {'text': '9 mins', 'value': 529},
#     'end_address': 'University of San Francisco - Folger Building, 101 Howard St, San Francisco, CA 94105, USA',
#     'end_location': {'lat': 37.7910969, 'lng': -122.3928065},
#     'start_address': '1422 Powell St, San Francisco, CA 94133, USA',
#     'start_location': {'lat': 37.7978914, 'lng': -122.4103637},
#     'steps': [{'distance': {'text': '157 ft', 'value': 48},
#       'duration': {'text': '1 min', 'value': 16},
#       'end_location': {'lat': 37.7974619, 'lng': -122.4102964},
#       'html_instructions': 'Head <b>south</b> on <b>Powell St</b> toward <b>Broadway</b>',
#       'polyline': {'points': 'ykueFvgcjVD?NADAx@G'},
#       'start_location': {'lat': 37.7978914, 'lng': -122.4103637},
# ...

# %%
len(route_info['routes'])
# Out:
# 3

# %%
route_points_1 = []
for point in route_info['routes'][1]['legs'][0]['steps']:
    route_points_1.append(point['end_location'])

# %%
route_points_1
# Out:
# [{'lat': 37.7974619, 'lng': -122.4102964},
#  {'lat': 37.7985907, 'lng': -122.4010735},
#  {'lat': 37.7932627, 'lng': -122.3999983},
#  {'lat': 37.7935225, 'lng': -122.3976275},
#  {'lat': 37.792584, 'lng': -122.3974392},
#  {'lat': 37.7899114, 'lng': -122.3943048},
#  {'lat': 37.7910969, 'lng': -122.3928065}]
