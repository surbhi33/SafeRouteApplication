# %%
import requests


url = "https://maps.googleapis.com/maps/api/directions/json?origin=Toronto&destination=Montreal&key=AIzaSyCINW6uGcvCKu9J-8AkdKFt4YcBObovM94"

payload={}
headers = {}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {
#    "geocoded_waypoints" : [
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJpTvG15DL1IkRd8S0KlBVNTI",
#          "types" : [ "locality", "political" ]
#       },
#       {
#          "geocoder_status" : "OK",
#          "place_id" : "ChIJDbdkHFQayUwR7-8fITgxTmU",
#          "types" : [ "locality", "political" ]
#       }
#    ],
#    "routes" : [
#       {
#          "bounds" : {
#             "northeast" : {
#                "lat" : 45.5017123,
#                "lng" : -73.5672184
#             },
#             "southwest" : {
#                "lat" : 43.6533961,
#                "lng" : -79.3834913
#             }
#          },
#          "copyrights" : "Map data ©2022 Google",
#          "legs" : [
#             {
#                "distance" : {
#                   "text" : "541 km",
#                   "value" : 540546
#                },
#                "duration" : {
#                   "text" : "5 hours 25 mins",
# ...

# %%
#!pip install gmplot
# Out:
# ...
#      |████████████████████████████████| 164 kB 3.6 MB/s eta 0:00:01
# ...

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap('AIzaSyCINW6uGcvCKu9J-8AkdKFt4YcBObovM94', gmap_options, title='Geneva', 
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
import pandas as pd
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1003">Loading BokehJS ...</span>
#     </div>

# %%
#!jupyter nbextension enable --py gmap

# %%
lat = 46.2437
lon= 6.0251
plot(lat, lon)
# Out:
#   <div class="bk-root" id="fd79316f-ded7-4da4-9b7c-02b4cf74a88b" data-root-id="1005"></div>
# GMap(id='1005', ...)

# %%
from gmplot import *

latitude_list = [ 28.530461, 28.530160, 28.544034, 28.524160, 28.520541]
longitude_list = [ 77.222742, 77.202315, 77.206435, 77.192372, 77.202157]

# First two arguments are latitude and longitude
# Third argument is the zoom level
gmap = gmplot.GoogleMapPlotter(28.530914, 77.211756, 15)

gmap.scatter(latitude_list, longitude_list, '#0000A0', size=90, marker=False)# Google API Key
gmap.apikey = "AIzaSyCINW6uGcvCKu9J-8AkdKFt4YcBObovM94"

# Set the location to save your file.
gmap.draw( "C:\\Python37\\Scripts\\projects\\googlemap.html" )
